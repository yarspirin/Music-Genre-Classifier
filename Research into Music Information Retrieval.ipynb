# %% [markdown]
# # Music Information Retrieval (aka Music Genre Recognition)

# %% [markdown]
# ## Let's have a look at spectograms for samples of different genres

# %%
import scipy.io.wavfile
import glob
import numpy as np
import os
import matplotlib.pyplot as plt
from matplotlib.pyplot import specgram
from scikits.talkbox.features import mfcc
# %matplotlib inline

# %% [markdown]
# # 1. Blues

# %%
sample_rate, X = scipy.io.wavfile.read('genres/blues/blues.00000.wav', 'r')
specgram(X, Fs=sample_rate, xextent=(0, 30));

# %% [markdown]
# # 2. Classical

# %%
sample_rate, X = scipy.io.wavfile.read('genres/classical/classical.00000.wav')
specgram(X, Fs=sample_rate, xextent=(0, 30));

# %% [markdown]
# # 3. Country

# %%
sample_rate, X = scipy.io.wavfile.read('genres/country/country.00000.wav')
specgram(X, Fs=sample_rate, xextent=(0, 30));

# %% [markdown]
# # 4. Disco

# %%
sample_rate, X = scipy.io.wavfile.read('genres/disco/disco.00000.wav')
specgram(X, Fs=sample_rate, xextent=(0, 30));

# %% [markdown]
# # 5. Hiphop

# %%
sample_rate, X = scipy.io.wavfile.read('genres/hiphop/hiphop.00000.wav')
specgram(X, Fs=sample_rate, xextent=(0, 30));

# %% [markdown]
# # 6. Jazz

# %%
sample_rate, X = scipy.io.wavfile.read('genres/jazz/jazz.00000.wav')
specgram(X, Fs=sample_rate, xextent=(0, 30));

# %% [markdown]
# # 7. Metal

# %%
sample_rate, X = scipy.io.wavfile.read('genres/metal/metal.00000.wav')
specgram(X, Fs=sample_rate, xextent=(0, 30));

# %% [markdown]
# # 8. Pop

# %%
sample_rate, X = scipy.io.wavfile.read('genres/pop/pop.00000.wav')
specgram(X, Fs=sample_rate, xextent=(0, 30));

# %% [markdown]
# # 9. Reggae

# %%
sample_rate, X = scipy.io.wavfile.read('genres/reggae/reggae.00000.wav')
specgram(X, Fs=sample_rate, xextent=(0, 30));

# %% [markdown]
# # 10. Rock

# %%
sample_rate, X = scipy.io.wavfile.read('genres/rock/rock.00000.wav')
specgram(X, Fs=sample_rate, xextent=(0, 30));

# %% [markdown]
# # We can make observations based on the spectograms

# %% [markdown]
# # Challenge:
# ## Let's create features for samples and then build a classifier that guess songs genre. The following project is expected to be in the same repo. :)
